# %%
print("Hello Databricks!")
# Out:
# Hello Databricks!

# %% [markdown]
# testing cluster

# %%
from pyspark.sql import SparkSession

data = [
    (1, "2026-05-01 08:15:00", "Berlin"),
    (2, "2026-05-01 09:20:00", "Hamburg"),
    (3, "2026-05-01 10:30:00", "Berlin"),
    (1, "2026-05-02 08:00:00", "Berlin"),
    (4, "2026-05-02 11:45:00", "Munich"),
    (5, "2026-05-03 14:20:00", "Cologne")
]

columns = ["user_id", "login_time", "city"]

df = spark.createDataFrame(data, columns)

df.show()
# Out:
# +-------+-------------------+-------+
# |user_id|         login_time|   city|
# +-------+-------------------+-------+
# |      1|2026-05-01 08:15:00| Berlin|
# |      2|2026-05-01 09:20:00|Hamburg|
# |      3|2026-05-01 10:30:00| Berlin|
# |      1|2026-05-02 08:00:00| Berlin|
# |      4|2026-05-02 11:45:00| Munich|
# |      5|2026-05-03 14:20:00|Cologne|
# +-------+-------------------+-------+

# %%
type(spark)
# Out:
# pyspark.sql.connect.session.SparkSession

# %%
df = spark.read.csv(
    "/Volumes/workspace/default/raw_data/usr_login_data.csv",
    header=True,
    inferSchema=True
)

df.show()
# Out:
# +-------+-------------------+-------+----+----+----+----+
# |user_id|         login_time|   city| _c3| _c4| _c5| _c6|
# +-------+-------------------+-------+----+----+----+----+
# |      1|2026-05-01 08:15:00| Berlin|NULL|NULL|NULL|NULL|
# |      2|2026-05-01 09:20:00|Hamburg|NULL|NULL|NULL|NULL|
# |      3|2026-05-01 10:30:00| Berlin|NULL|NULL|NULL|NULL|
# |      4|2026-05-02 11:45:00| Munich|NULL|NULL|NULL|NULL|
# |      5|2026-05-03 14:20:00|Cologne|NULL|NULL|NULL|NULL|
# +-------+-------------------+-------+----+----+----+----+

# %%
df.printSchema()
# Out:
# root
#  |-- user_id: integer (nullable = true)
#  |-- login_time: timestamp (nullable = true)
#  |-- city: string (nullable = true)
#  |-- _c3: string (nullable = true)
#  |-- _c4: string (nullable = true)
#  |-- _c5: string (nullable = true)
#  |-- _c6: string (nullable = true)

# %%
df_clean = df.select(
    "user_id",
    "login_time",
    "city"
)

df_clean.show()
# Out:
# +-------+-------------------+-------+
# |user_id|         login_time|   city|
# +-------+-------------------+-------+
# |      1|2026-05-01 08:15:00| Berlin|
# |      2|2026-05-01 09:20:00|Hamburg|
# |      3|2026-05-01 10:30:00| Berlin|
# |      4|2026-05-02 11:45:00| Munich|
# |      5|2026-05-03 14:20:00|Cologne|
# +-------+-------------------+-------+

# %%
df_clean.groupBy("city").count().show()
# Out:
# +-------+-----+
# |   city|count|
# +-------+-----+
# |Hamburg|    1|
# | Berlin|    2|
# | Munich|    1|
# |Cologne|    1|
# +-------+-----+
